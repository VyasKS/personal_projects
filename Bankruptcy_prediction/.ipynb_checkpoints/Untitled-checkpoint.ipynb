# %% [markdown]
# ## Project report for Machine Learning (VO) [05.16034]. Professor Alberto Santini, RWTH AACHEN UNIVERSITY, DEUTSCHLAND.
#
# ## Contents
# <ol>
#     <b><li>Importing necessary libraries</li></b>
#     <li><b>Data import and manipulation</b>
#         <ol>
#             <li>Converting the columns types for the features to float</li>
#             <li>Converting the class label types to int</li>
#         </ol>
#     </li>
#     <li><b>Data Analysis and Preprocessing</b>
#         <ol>
#             <li>Missing Data Analysis
#                 <ol>
#                     <li>Generating Sparsity Matrix for the missing data</li>
#                     <li>Generating Heat Map for the missing data</li>
#                 </ol>
#             </li>
#             <li>Data Imputation
#                 <ol>
#                     <li>Mean Imputation</li>
#                     <li>K-NN</li>
#                     <li>EM</li>
#                     <li>MICE</li>
#                 </ol>
#             </li>
#             <li>Dealing with imbalanced data
#                 <ol>
#                     <li>Oversampling with SMOTE</li>
#                 </ol>
#             </li>
#         </ol>
#     </li>
#     <li><b>Data Modeling</b>
#         <ol>
#             <li>K-Fold Cross validation</li>
#             <li>Models
#                 <ol>
#                     <li>Gaussian Naive Bayes classifier</li>
#                     <li>Logistic Regression classifier</li>
#                     <li>Decision Tree classifier</li>
#                     <li>Random Forest classifier</li>
#                     <li>Extreme Gradient Boosting classifier</li>
#                     <li>Balanced Bagging classifier</li>
#                 </ol>
#             </li>
#         </ol>
#     </li>
#     <li><b>Model Analysis</b>
#         <ol>
#             <li>Model ranking</li>
#             <li>Balanced Bagging: Effect of varying number of estimators on the accuracy scores on different datasets</li>
#             <li>Balanced Bagging: Plotting effect of number of estimators on Accuracy</li>
#         </ol>
#     </li>
#     <li><b>References</b></li>
# </ol>

# %% [markdown]
# ### Importing necessary libraries

# %%
# Supressing warnings
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Libraries for data manipulation, statistical operations and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.io import arff                                                                  # to load .arff files
import missingno as msno                                                                   # to analyze type of missing data
import fancyimpute                                                                         # For performing k-NN and MICE imputations
import impyute as impy                                                                     # For performing Expectation Maximization (EM) imputation
from sklearn.impute import SimpleImputer                                                   # For performing Mean imputation
from sklearn.impute import IterativeImputer                                                # Using this in place of MICE (Multiple Imputation by Chained Equations)

from sklearn.model_selection import KFold                                                  # For performing kFold cross-validation
from collections import Counter                                                            # For counting class objects ( elements as keys, their count as values)
from collections import OrderedDict                                                        # For dictionary operations
from imblearn.over_sampling import SMOTE                                                   # To perform SMOTE oversampling while dealing with imbalanced data

import sklearn
from xgboost import XGBClassifier                                                          # Importing classification models for modeling
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from imblearn.ensemble import BalancedBaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

import random

# All metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, confusion_matrix, roc_curve, precision_recall_curve

# %% [markdown]
# ### 2. Data import and manipulation
#
# <b>Dataset Link:</b>The Dataset can be found at [Polish bankruptcy dataset](https://archive.ics.uci.edu/ml/datasets/Polish+companies+bankruptcy+data)
#
# There are a total of **5 .arff data files** with the names **`1year`, `2year`, `3year`, `4year`, `5year`**.
# Load the .arff files and convert them into pandas dataframes using the `load_dataframes` function.
# Give them new column headers using the function `set_new_headers`. The column labels for the features are like `X1`, `X2`, ... , `X64`. The class label is `Y`.
# Print the first 5 rows of a dataframe, to see how the data looks like.

# %%
# Loads the 5 raw .arff files into a list
def load_arff():
    n = 5
    return [arff.loadarff('data/' + str(i+1) + 'year.arff') for i in range(n)]

# Loads the 5 raw .arff files into pandas dataframes
def init_dataframes():
    return [pd.DataFrame(i_year[0]) for i_year in load_arff()]

# Sets column headers as X1,...X64 and label as Y for all 5 dataframes
def set_new_headers(dataframes):
    cols = ['X' + str(i+1) for i in range(len(dataframes[0].columns)-1)]
    cols.append('Y')
    for df in dataframes:
        df.columns = cols

# Objects are a list of pandas dataframes for the 5 year datafiles
dataframes = init_dataframes()

# Sets new headers for the dataframes with renamed set of features (X1 to X64) and a label (Y)
set_new_headers(dataframes)

# print the first 5 rows of a dataset 'year1'
dataframes[0].head()
# Out:
#          X1       X2       X3      X4       X5       X6        X7       X8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#        X9      X10  ...       X56      X57      X58       X59     X60     X61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#        X62     X63      X64     Y
# 0   82.658  4.4158   7.4277  b'0'
# 1  107.350  3.4000  60.9870  b'0'
# 2  134.270  2.7185   5.2078  b'0'
# 3   86.435  4.2228   5.5497  b'0'
# 4  127.210  2.8692   7.8980  b'0'
#
# [5 rows x 65 columns]

# %%
column_list = [dataframes[0].columns]
column_list
# Out:
# [Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#         'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21',
#         'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
#         'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40', 'X41',
#         'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49', 'X50', 'X51',
#         'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59', 'X60', 'X61',
#         'X62', 'X63', 'X64', 'Y'],
#        dtype='object')]

# %% [markdown]
# #### 2.A Converting the columns types for the features to float
# For consistency, we make all python objects as floating points across the dataframe except class label

# %%
def convert_to_float(df):
    for i in range(5):
        index = 1
        while index <= 63:
            colname = df[i].columns[index]
            col = getattr(df[i], colname)
            df[i][colname] = col.astype(float)
            index += 1
convert_to_float(dataframes)

# %% [markdown]
# #### 2.B Converting the class label types to int
# If we look the class label `Y`, we notice that the values are shown either as `b'0'` or `b'1'`
# They actually correspond to bankruptcy being false and true respectively. It is convenient to convert them to binary integers 0 and 1 respectively from objects to int.

# %%
def convert_classlabel(df):
    for i in range(len(df)):
        col = getattr(df[i], 'Y')
        df[i]['Y'] = col.astype(int)
        
convert_classlabel(dataframes)

# %% [markdown]
# ## 3. Data Analysis and Preprocessing
# ### 3.A Missing Data Analysis

# %%
""" Note that our 'dataframes' is actually a list of dataframes for all five years of data"""

class Data:
    
    """ All basic operations we perform on the dataset are created under this class"""
    
    def __init__(self, dataframes):
        """ Initializes the class with dataframes as argument"""
        self.dataframes = dataframes
        
    def drop_missing(self, verbose=False):
        """ Drops the missing values and shows the effects of doing so in numbers"""
        cleaned = [df.dropna(axis=0, how='any') for df in self.dataframes]
        if verbose:
            for i in range(len(self.dataframes)):
                print(str(i+1) + 'year:', 'Original length=', len(self.dataframes[i]), '\tCleaned length = ', len(cleaned[i]), '\tMissing data = ', len(self.dataframes[i] - cleaned[i]))
        else:
            return cleaned
    
    def generate_sparsity_matrix(self):
        """ Generates Sparsity Matrix for the missing data in all dataframes"""
        for i in range(5):
            missing_values = self.dataframes[i].columns[self.dataframes[i].isnull().any()].tolist() # Making a list of all missing values in all 5 dataframes
            msno.matrix(self.dataframes[i][missing_values], figsize=(20,5))
    
    def generate_heatmaps_missing_values(self):
        """ Generates heatmaps for missing values in all dataframes and displays respective correlations among features in a ascending tabular form"""
        for i in range(5):
            missing_values = self.dataframes[i].columns[self.dataframes[i].isnull().any()].tolist() # Making a list of all missing values in all 5 dataframes
            msno.heatmap(self.dataframes[i][missing_values], figsize=(20,20))
    
    def do_mean_imputation(self):
        """ Performs mean imputation method on missing values on all dataframes passed as argument and returns a list of dataframes of same length as of argument"""
        imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
        imputed_dataframes = [pd.DataFrame(imputer.fit_transform(dfs)) for dfs in self.dataframes]
        for i in range(len(self.dataframes)):
            imputed_dataframes[i].columns = self.dataframes[i].columns
        return imputed_dataframes
    
    def do_knn_imputation(self):
        """ Performs KNN imputation on missing values in all dataframes passed as argument and returns a list of dataframes of same length as of argument"""
        imputed_dataframes = [fancyimpute.KNN(k=100, verbose=True).fit_transform(self.dataframes[i]) for i in range(len(self.dataframes))]
        return [pd.DataFrame(data = imputed_dataframes[i]) for i in range(len(self.dataframes))]
    
    def do_EM_imputation(self):
        """ Performs Expectation Maximization imputation on all dataframes passed as argument and returns a list of dataframes of same length as of argument"""
        imputed_dataframes = [impy.imputation.cs.em(self.dataframes[i].values, loops = 50, dtype = 'cont') for i in range(len(self.dataframes))]
        return [pd.DataFrame(data = imputed_dataframes[i]) for i in range(len(self.dataframes))]
    
    def do_MICE_imputation(self):
        """ Using Sklearn's Iterative Imputer which is inspired by MICE imputer as unable to import MICE imputer module"""
        """ Performs MICE (Multiple Imputation from Chained Equations) on all dataframes passed as argument and returns a list of dataframes of same length as of argument"""
        imputed_dataframes = [IterativeImputer(max_iter=10, random_state=10, verbose=False).fit_transform(self.dataframes[i]) for i in range(len(self.dataframes))]
        return [pd.DataFrame(data = imputed_dataframes[i]) for i in range(len(self.dataframes))]
           
    def set_header(self):
        """ Sets column names for all columns as X1, X2...X63 for all features and Y for label"""
        columns = ['X' + str(i+1) for i in range(len(self.dataframes[0].columns)-1)]
        columns.append('Y')
        for df in self.dataframes:
            df.columns = columns

# %%
# Doing a quick analysis of how many missing values are there in each of the 5 dataframes
Data = Data(dataframes)

# %%
Data.drop_missing(verbose=True)
# Out:
# 1year: Original length= 7027 	Cleaned length =  3194 	Missing data =  7027
# 2year: Original length= 10173 	Cleaned length =  4088 	Missing data =  10173
# 3year: Original length= 10503 	Cleaned length =  4885 	Missing data =  10503
# 4year: Original length= 9792 	Cleaned length =  4769 	Missing data =  9792
# 5year: Original length= 5910 	Cleaned length =  3031 	Missing data =  5910

# %% [markdown]
# Clearly there is a lot of missing data approximately more than 50% of data among features is missing for all dataframes for years (1 to 5). Atleast 1 feature is having missing data.
# This is a big problem when dealing with datasets. Let us proceed further and get few insights out of the missing values using our Missing_data() class
#
# #### 3.A.a Generating Sparsity Matrix for the missing data
# Finding whether missing data has some correlation is a vital task to perform. The `matrix` function from the `missingno` library helps us generate sparsity matrix, which shows us the gaps in the data.

# %%
Data.generate_sparsity_matrix()

# %% [markdown]
# From the above plots of sparsity for all the 5 dataframes, we could notice a lot of sparsity for the feature `X37` has the highest sparsity among all the features for all the dataframes. The feature `X21` is sparse for some, if not all, dataframes. Also, more or less, all the features have missing data samples. From the above sparsity-plot, we could only know how sparse the data is, yet we don't know if the data missing-ness is correlated among any features, i.e., is the data missing completely at random? Or are there any features that are missing together? as a next step, let us find out if there is some correlation among the features.
#
# However, it is clear that simply dropping all the rows with missing values, or eliminating all the features which have missing values is not a good approach of dealing with the missing data, as it leads to tremendous data loss.
#
# #### 3.A.b Generating Heat Map for the missing data
# Checking if there is some correlation among the missing features.
# Using the `heatmap` function from `missingno` library, following are the heatmaps for all dataframes.

# %%
Data.generate_heatmaps_missing_values()

# %% [markdown]
# The heat maps above, for all the 5 dataframes, describe the degree of nullity relationship between different features.    The range of this nullity correlation is from -1 to 1 (-1 ≤ R ≤ 1).
# Features with no missing value are excluded in the heatmap. If the nullity correlation is very close to zero (-0.05 < R < 0.05), no value will be displayed.
#
# A perfect positive nullity correlation (R=1) indicates when the first feature and the second feature both have corresponding missing values.
#
# A perfect negative nullity correlation (R=-1) means that one of the features is missing and the second is not missing.
#
# The takeaway is that, in each dataframe, there are some features that are heavily correlated (R = 1 or -1) and also there are features that are not essentially correlated (R values close to 0)
#
# ### 3.B Data Imputation
#
# It is now established that we need to impute (fill in the gaps) the missing data, as dropping the missing rows or eliminating the missing features is not an option.
#
# We would like to explore some of the widely used missing data imputation techniques.
# <b>
# 1. Mean Imputation (baseline method)
# 2. k Nearest Neighbors (k-NN) Imputation
# 3. Expectation-Maximization (EM) Imputation
# 4. Multivariate Imputation using Chained Equations (MICE)
# </b>
#
# #### 3.B.a Mean Imputation

# %%
m = Data.do_mean_imputation()

# %% [markdown]
# #### 3.B.b k-Nearest Neighbors (k-NN) Imputation

# %%
knn = Data.do_knn_imputation()
set_new_headers(knn)
# Out:
# Imputing row 1/7027 with 0 missing, elapsed time: 19.830
# Imputing row 101/7027 with 1 missing, elapsed time: 19.836
# Imputing row 201/7027 with 2 missing, elapsed time: 19.843
# Imputing row 301/7027 with 0 missing, elapsed time: 19.849
# Imputing row 401/7027 with 0 missing, elapsed time: 19.854
# Imputing row 501/7027 with 1 missing, elapsed time: 19.859
# Imputing row 601/7027 with 1 missing, elapsed time: 19.863
# Imputing row 701/7027 with 1 missing, elapsed time: 19.868
# Imputing row 801/7027 with 0 missing, elapsed time: 19.873
# Imputing row 901/7027 with 0 missing, elapsed time: 19.877
# Imputing row 1001/7027 with 1 missing, elapsed time: 19.883
# Imputing row 1101/7027 with 1 missing, elapsed time: 19.887
# Imputing row 1201/7027 with 3 missing, elapsed time: 19.893
# Imputing row 1301/7027 with 1 missing, elapsed time: 19.898
# Imputing row 1401/7027 with 1 missing, elapsed time: 19.902
# Imputing row 1501/7027 with 1 missing, elapsed time: 19.907
# Imputing row 1601/7027 with 1 missing, elapsed time: 19.912
# Imputing row 1701/7027 with 2 missing, elapsed time: 19.917
# Imputing row 1801/7027 with 1 missing, elapsed time: 19.921
# Imputing row 1901/7027 with 33 missing, elapsed time: 19.927
# Imputing row 2001/7027 with 0 missing, elapsed time: 19.933
# Imputing row 2101/7027 with 2 missing, elapsed time: 19.937
# Imputing row 2201/7027 with 1 missing, elapsed time: 19.942
# Imputing row 2301/7027 with 1 missing, elapsed time: 19.947
# Imputing row 2401/7027 with 0 missing, elapsed time: 19.952
# Imputing row 2501/7027 with 1 missing, elapsed time: 19.959
# Imputing row 2601/7027 with 0 missing, elapsed time: 19.964
# Imputing row 2701/7027 with 0 missing, elapsed time: 19.970
# Imputing row 2801/7027 with 1 missing, elapsed time: 19.975
# Imputing row 2901/7027 with 1 missing, elapsed time: 19.980
# Imputing row 3001/7027 with 0 missing, elapsed time: 19.985
# Imputing row 3101/7027 with 2 missing, elapsed time: 19.989
# Imputing row 3201/7027 with 1 missing, elapsed time: 19.994
# Imputing row 3301/7027 with 0 missing, elapsed time: 19.998
# Imputing row 3401/7027 with 0 missing, elapsed time: 20.003
# Imputing row 3501/7027 with 0 missing, elapsed time: 20.008
# Imputing row 3601/7027 with 1 missing, elapsed time: 20.012
# Imputing row 3701/7027 with 1 missing, elapsed time: 20.018
# Imputing row 3801/7027 with 0 missing, elapsed time: 20.023
# Imputing row 3901/7027 with 0 missing, elapsed time: 20.026
# Imputing row 4001/7027 with 1 missing, elapsed time: 20.031
# Imputing row 4101/7027 with 1 missing, elapsed time: 20.036
# Imputing row 4201/7027 with 1 missing, elapsed time: 20.041
# Imputing row 4301/7027 with 1 missing, elapsed time: 20.046
# Imputing row 4401/7027 with 0 missing, elapsed time: 20.050
# Imputing row 4501/7027 with 0 missing, elapsed time: 20.057
# Imputing row 4601/7027 with 0 missing, elapsed time: 20.067
# Imputing row 4701/7027 with 1 missing, elapsed time: 20.074
# Imputing row 4801/7027 with 0 missing, elapsed time: 20.079
# Imputing row 4901/7027 with 1 missing, elapsed time: 20.083
# Imputing row 5001/7027 with 1 missing, elapsed time: 20.089
# Imputing row 5101/7027 with 0 missing, elapsed time: 20.095
# Imputing row 5201/7027 with 0 missing, elapsed time: 20.099
# Imputing row 5301/7027 with 1 missing, elapsed time: 20.104
# Imputing row 5401/7027 with 0 missing, elapsed time: 20.110
# Imputing row 5501/7027 with 0 missing, elapsed time: 20.113
# Imputing row 5601/7027 with 9 missing, elapsed time: 20.116
# Imputing row 5701/7027 with 2 missing, elapsed time: 20.119
# Imputing row 5801/7027 with 0 missing, elapsed time: 20.124
# Imputing row 5901/7027 with 1 missing, elapsed time: 20.128
# Imputing row 6001/7027 with 0 missing, elapsed time: 20.134
# Imputing row 6101/7027 with 0 missing, elapsed time: 20.139
# Imputing row 6201/7027 with 0 missing, elapsed time: 20.144
# Imputing row 6301/7027 with 0 missing, elapsed time: 20.149
# Imputing row 6401/7027 with 1 missing, elapsed time: 20.153
# Imputing row 6501/7027 with 3 missing, elapsed time: 20.158
# Imputing row 6601/7027 with 0 missing, elapsed time: 20.162
# Imputing row 6701/7027 with 1 missing, elapsed time: 20.167
# Imputing row 6801/7027 with 1 missing, elapsed time: 20.174
# Imputing row 6901/7027 with 1 missing, elapsed time: 20.181
# Imputing row 7001/7027 with 3 missing, elapsed time: 20.188
# Imputing row 1/10173 with 0 missing, elapsed time: 42.367
# Imputing row 101/10173 with 3 missing, elapsed time: 42.377
# Imputing row 201/10173 with 0 missing, elapsed time: 42.386
# Imputing row 301/10173 with 1 missing, elapsed time: 42.398
# Imputing row 401/10173 with 0 missing, elapsed time: 42.409
# Imputing row 501/10173 with 0 missing, elapsed time: 42.417
# Imputing row 601/10173 with 0 missing, elapsed time: 42.425
# Imputing row 701/10173 with 1 missing, elapsed time: 42.432
# Imputing row 801/10173 with 0 missing, elapsed time: 42.438
# Imputing row 901/10173 with 1 missing, elapsed time: 42.447
# Imputing row 1001/10173 with 0 missing, elapsed time: 42.455
# Imputing row 1101/10173 with 2 missing, elapsed time: 42.463
# Imputing row 1201/10173 with 1 missing, elapsed time: 42.473
# Imputing row 1301/10173 with 0 missing, elapsed time: 42.484
# Imputing row 1401/10173 with 0 missing, elapsed time: 42.494
# Imputing row 1501/10173 with 4 missing, elapsed time: 42.504
# Imputing row 1601/10173 with 0 missing, elapsed time: 42.513
# Imputing row 1701/10173 with 1 missing, elapsed time: 42.522
# Imputing row 1801/10173 with 0 missing, elapsed time: 42.530
# Imputing row 1901/10173 with 1 missing, elapsed time: 42.541
# Imputing row 2001/10173 with 1 missing, elapsed time: 42.550
# Imputing row 2101/10173 with 0 missing, elapsed time: 42.559
# Imputing row 2201/10173 with 0 missing, elapsed time: 42.569
# Imputing row 2301/10173 with 1 missing, elapsed time: 42.582
# Imputing row 2401/10173 with 0 missing, elapsed time: 42.597
# Imputing row 2501/10173 with 1 missing, elapsed time: 42.609
# Imputing row 2601/10173 with 1 missing, elapsed time: 42.618
# Imputing row 2701/10173 with 0 missing, elapsed time: 42.627
# Imputing row 2801/10173 with 1 missing, elapsed time: 42.638
# Imputing row 2901/10173 with 2 missing, elapsed time: 42.645
# Imputing row 3001/10173 with 1 missing, elapsed time: 42.654
# Imputing row 3101/10173 with 0 missing, elapsed time: 42.662
# Imputing row 3201/10173 with 2 missing, elapsed time: 42.670
# Imputing row 3301/10173 with 1 missing, elapsed time: 42.680
# Imputing row 3401/10173 with 1 missing, elapsed time: 42.690
# Imputing row 3501/10173 with 0 missing, elapsed time: 42.702
# Imputing row 3601/10173 with 0 missing, elapsed time: 42.711
# Imputing row 3701/10173 with 4 missing, elapsed time: 42.722
# Imputing row 3801/10173 with 1 missing, elapsed time: 42.734
# Imputing row 3901/10173 with 1 missing, elapsed time: 42.744
# Imputing row 4001/10173 with 1 missing, elapsed time: 42.754
# Imputing row 4101/10173 with 0 missing, elapsed time: 42.763
# Imputing row 4201/10173 with 33 missing, elapsed time: 42.772
# Imputing row 4301/10173 with 0 missing, elapsed time: 42.784
# Imputing row 4401/10173 with 2 missing, elapsed time: 42.806
# Imputing row 4501/10173 with 0 missing, elapsed time: 42.814
# Imputing row 4601/10173 with 0 missing, elapsed time: 42.829
# Imputing row 4701/10173 with 4 missing, elapsed time: 42.839
# Imputing row 4801/10173 with 0 missing, elapsed time: 42.846
# Imputing row 4901/10173 with 1 missing, elapsed time: 42.853
# Imputing row 5001/10173 with 2 missing, elapsed time: 42.861
# Imputing row 5101/10173 with 1 missing, elapsed time: 42.868
# Imputing row 5201/10173 with 1 missing, elapsed time: 42.875
# Imputing row 5301/10173 with 1 missing, elapsed time: 42.886
# Imputing row 5401/10173 with 1 missing, elapsed time: 42.898
# Imputing row 5501/10173 with 1 missing, elapsed time: 42.909
# Imputing row 5601/10173 with 1 missing, elapsed time: 42.917
# Imputing row 5701/10173 with 2 missing, elapsed time: 42.923
# Imputing row 5801/10173 with 2 missing, elapsed time: 42.931
# Imputing row 5901/10173 with 1 missing, elapsed time: 42.938
# Imputing row 6001/10173 with 0 missing, elapsed time: 42.946
# Imputing row 6101/10173 with 6 missing, elapsed time: 42.954
# Imputing row 6201/10173 with 0 missing, elapsed time: 42.965
# Imputing row 6301/10173 with 0 missing, elapsed time: 42.972
# Imputing row 6401/10173 with 1 missing, elapsed time: 42.984
# Imputing row 6501/10173 with 1 missing, elapsed time: 43.004
# Imputing row 6601/10173 with 1 missing, elapsed time: 43.014
# Imputing row 6701/10173 with 5 missing, elapsed time: 43.027
# Imputing row 6801/10173 with 0 missing, elapsed time: 43.034
# Imputing row 6901/10173 with 2 missing, elapsed time: 43.040
# Imputing row 7001/10173 with 2 missing, elapsed time: 43.048
# Imputing row 7101/10173 with 2 missing, elapsed time: 43.056
# Imputing row 7201/10173 with 1 missing, elapsed time: 43.062
# Imputing row 7301/10173 with 1 missing, elapsed time: 43.072
# Imputing row 7401/10173 with 3 missing, elapsed time: 43.083
# Imputing row 7501/10173 with 0 missing, elapsed time: 43.089
# Imputing row 7601/10173 with 0 missing, elapsed time: 43.093
# Imputing row 7701/10173 with 1 missing, elapsed time: 43.099
# Imputing row 7801/10173 with 0 missing, elapsed time: 43.105
# Imputing row 7901/10173 with 1 missing, elapsed time: 43.111
# Imputing row 8001/10173 with 0 missing, elapsed time: 43.118
# Imputing row 8101/10173 with 0 missing, elapsed time: 43.125
# Imputing row 8201/10173 with 0 missing, elapsed time: 43.129
# Imputing row 8301/10173 with 1 missing, elapsed time: 43.135
# Imputing row 8401/10173 with 0 missing, elapsed time: 43.145
# Imputing row 8501/10173 with 3 missing, elapsed time: 43.152
# Imputing row 8601/10173 with 0 missing, elapsed time: 43.162
# Imputing row 8701/10173 with 0 missing, elapsed time: 43.171
# Imputing row 8801/10173 with 0 missing, elapsed time: 43.179
# Imputing row 8901/10173 with 2 missing, elapsed time: 43.191
# Imputing row 9001/10173 with 2 missing, elapsed time: 43.201
# Imputing row 9101/10173 with 2 missing, elapsed time: 43.215
# Imputing row 9201/10173 with 0 missing, elapsed time: 43.224
# Imputing row 9301/10173 with 1 missing, elapsed time: 43.235
# Imputing row 9401/10173 with 0 missing, elapsed time: 43.246
# Imputing row 9501/10173 with 2 missing, elapsed time: 43.258
# Imputing row 9601/10173 with 0 missing, elapsed time: 43.267
# Imputing row 9701/10173 with 1 missing, elapsed time: 43.275
# Imputing row 9801/10173 with 1 missing, elapsed time: 43.284
# Imputing row 9901/10173 with 1 missing, elapsed time: 43.295
# Imputing row 10001/10173 with 1 missing, elapsed time: 43.305
# Imputing row 10101/10173 with 0 missing, elapsed time: 43.317
# Imputing row 1/10503 with 0 missing, elapsed time: 43.637
# Imputing row 101/10503 with 0 missing, elapsed time: 43.647
# Imputing row 201/10503 with 2 missing, elapsed time: 43.657
# Imputing row 301/10503 with 1 missing, elapsed time: 43.666
# Imputing row 401/10503 with 0 missing, elapsed time: 43.677
# Imputing row 501/10503 with 1 missing, elapsed time: 43.683
# Imputing row 601/10503 with 0 missing, elapsed time: 43.688
# Imputing row 701/10503 with 1 missing, elapsed time: 43.695
# Imputing row 801/10503 with 0 missing, elapsed time: 43.700
# Imputing row 901/10503 with 1 missing, elapsed time: 43.708
# Imputing row 1001/10503 with 1 missing, elapsed time: 43.713
# Imputing row 1101/10503 with 1 missing, elapsed time: 43.721
# Imputing row 1201/10503 with 0 missing, elapsed time: 43.728
# Imputing row 1301/10503 with 2 missing, elapsed time: 43.737
# Imputing row 1401/10503 with 1 missing, elapsed time: 43.746
# Imputing row 1501/10503 with 4 missing, elapsed time: 43.754
# Imputing row 1601/10503 with 1 missing, elapsed time: 43.762
# Imputing row 1701/10503 with 0 missing, elapsed time: 43.770
# Imputing row 1801/10503 with 1 missing, elapsed time: 43.777
# Imputing row 1901/10503 with 0 missing, elapsed time: 43.784
# Imputing row 2001/10503 with 1 missing, elapsed time: 43.793
# Imputing row 2101/10503 with 1 missing, elapsed time: 43.802
# Imputing row 2201/10503 with 0 missing, elapsed time: 43.808
# Imputing row 2301/10503 with 0 missing, elapsed time: 43.817
# Imputing row 2401/10503 with 0 missing, elapsed time: 43.824
# Imputing row 2501/10503 with 3 missing, elapsed time: 43.831
# Imputing row 2601/10503 with 1 missing, elapsed time: 43.836
# Imputing row 2701/10503 with 0 missing, elapsed time: 43.845
# Imputing row 2801/10503 with 1 missing, elapsed time: 43.853
# Imputing row 2901/10503 with 0 missing, elapsed time: 43.860
# Imputing row 3001/10503 with 1 missing, elapsed time: 43.865
# Imputing row 3101/10503 with 0 missing, elapsed time: 43.875
# Imputing row 3201/10503 with 0 missing, elapsed time: 43.887
# Imputing row 3301/10503 with 1 missing, elapsed time: 43.894
# Imputing row 3401/10503 with 0 missing, elapsed time: 43.902
# Imputing row 3501/10503 with 1 missing, elapsed time: 43.909
# Imputing row 3601/10503 with 0 missing, elapsed time: 43.922
# Imputing row 3701/10503 with 1 missing, elapsed time: 43.931
# Imputing row 3801/10503 with 2 missing, elapsed time: 43.940
# Imputing row 3901/10503 with 0 missing, elapsed time: 43.949
# Imputing row 4001/10503 with 0 missing, elapsed time: 43.957
# Imputing row 4101/10503 with 1 missing, elapsed time: 43.967
# Imputing row 4201/10503 with 1 missing, elapsed time: 43.975
# Imputing row 4301/10503 with 0 missing, elapsed time: 43.981
# Imputing row 4401/10503 with 1 missing, elapsed time: 43.990
# Imputing row 4501/10503 with 2 missing, elapsed time: 44.002
# Imputing row 4601/10503 with 1 missing, elapsed time: 44.009
# Imputing row 4701/10503 with 2 missing, elapsed time: 44.017
# Imputing row 4801/10503 with 0 missing, elapsed time: 44.025
# Imputing row 4901/10503 with 1 missing, elapsed time: 44.032
# Imputing row 5001/10503 with 0 missing, elapsed time: 44.038
# Imputing row 5101/10503 with 1 missing, elapsed time: 44.044
# Imputing row 5201/10503 with 0 missing, elapsed time: 44.052
# Imputing row 5301/10503 with 2 missing, elapsed time: 44.059
# Imputing row 5401/10503 with 3 missing, elapsed time: 44.067
# Imputing row 5501/10503 with 2 missing, elapsed time: 44.084
# Imputing row 5601/10503 with 1 missing, elapsed time: 44.094
# Imputing row 5701/10503 with 0 missing, elapsed time: 44.103
# Imputing row 5801/10503 with 0 missing, elapsed time: 44.109
# Imputing row 5901/10503 with 1 missing, elapsed time: 44.117
# Imputing row 6001/10503 with 1 missing, elapsed time: 44.125
# Imputing row 6101/10503 with 0 missing, elapsed time: 44.133
# Imputing row 6201/10503 with 0 missing, elapsed time: 44.139
# Imputing row 6301/10503 with 1 missing, elapsed time: 44.148
# Imputing row 6401/10503 with 0 missing, elapsed time: 44.156
# Imputing row 6501/10503 with 0 missing, elapsed time: 44.164
# Imputing row 6601/10503 with 0 missing, elapsed time: 44.172
# Imputing row 6701/10503 with 0 missing, elapsed time: 44.181
# Imputing row 6801/10503 with 2 missing, elapsed time: 44.188
# Imputing row 6901/10503 with 3 missing, elapsed time: 44.199
# Imputing row 7001/10503 with 1 missing, elapsed time: 44.205
# Imputing row 7101/10503 with 0 missing, elapsed time: 44.209
# Imputing row 7201/10503 with 3 missing, elapsed time: 44.215
# Imputing row 7301/10503 with 0 missing, elapsed time: 44.220
# Imputing row 7401/10503 with 1 missing, elapsed time: 44.227
# Imputing row 7501/10503 with 0 missing, elapsed time: 44.235
# Imputing row 7601/10503 with 0 missing, elapsed time: 44.242
# Imputing row 7701/10503 with 0 missing, elapsed time: 44.247
# Imputing row 7801/10503 with 2 missing, elapsed time: 44.250
# Imputing row 7901/10503 with 0 missing, elapsed time: 44.256
# Imputing row 8001/10503 with 1 missing, elapsed time: 44.260
# Imputing row 8101/10503 with 1 missing, elapsed time: 44.265
# Imputing row 8201/10503 with 0 missing, elapsed time: 44.270
# Imputing row 8301/10503 with 0 missing, elapsed time: 44.276
# Imputing row 8401/10503 with 1 missing, elapsed time: 44.282
# Imputing row 8501/10503 with 1 missing, elapsed time: 44.289
# Imputing row 8601/10503 with 1 missing, elapsed time: 44.297
# Imputing row 8701/10503 with 1 missing, elapsed time: 44.305
# Imputing row 8801/10503 with 0 missing, elapsed time: 44.312
# Imputing row 8901/10503 with 2 missing, elapsed time: 44.320
# Imputing row 9001/10503 with 2 missing, elapsed time: 44.328
# Imputing row 9101/10503 with 0 missing, elapsed time: 44.341
# Imputing row 9201/10503 with 0 missing, elapsed time: 44.348
# Imputing row 9301/10503 with 0 missing, elapsed time: 44.358
# Imputing row 9401/10503 with 0 missing, elapsed time: 44.366
# Imputing row 9501/10503 with 0 missing, elapsed time: 44.372
# Imputing row 9601/10503 with 1 missing, elapsed time: 44.379
# Imputing row 9701/10503 with 1 missing, elapsed time: 44.386
# Imputing row 9801/10503 with 1 missing, elapsed time: 44.393
# Imputing row 9901/10503 with 0 missing, elapsed time: 44.400
# Imputing row 10001/10503 with 1 missing, elapsed time: 44.405
# Imputing row 10101/10503 with 0 missing, elapsed time: 44.412
# Imputing row 10201/10503 with 1 missing, elapsed time: 44.420
# Imputing row 10301/10503 with 0 missing, elapsed time: 44.431
# Imputing row 10401/10503 with 1 missing, elapsed time: 44.444
# Imputing row 10501/10503 with 1 missing, elapsed time: 44.455
# Imputing row 1/9792 with 0 missing, elapsed time: 36.124
# Imputing row 101/9792 with 0 missing, elapsed time: 36.133
# Imputing row 201/9792 with 0 missing, elapsed time: 36.141
# Imputing row 301/9792 with 1 missing, elapsed time: 36.150
# Imputing row 401/9792 with 3 missing, elapsed time: 36.157
# Imputing row 501/9792 with 0 missing, elapsed time: 36.161
# Imputing row 601/9792 with 1 missing, elapsed time: 36.166
# Imputing row 701/9792 with 3 missing, elapsed time: 36.171
# Imputing row 801/9792 with 1 missing, elapsed time: 36.177
# Imputing row 901/9792 with 0 missing, elapsed time: 36.182
# Imputing row 1001/9792 with 0 missing, elapsed time: 36.189
# Imputing row 1101/9792 with 1 missing, elapsed time: 36.194
# Imputing row 1201/9792 with 3 missing, elapsed time: 36.201
# Imputing row 1301/9792 with 0 missing, elapsed time: 36.207
# Imputing row 1401/9792 with 1 missing, elapsed time: 36.214
# Imputing row 1501/9792 with 0 missing, elapsed time: 36.220
# Imputing row 1601/9792 with 1 missing, elapsed time: 36.226
# Imputing row 1701/9792 with 0 missing, elapsed time: 36.232
# Imputing row 1801/9792 with 1 missing, elapsed time: 36.239
# Imputing row 1901/9792 with 0 missing, elapsed time: 36.246
# Imputing row 2001/9792 with 0 missing, elapsed time: 36.254
# Imputing row 2101/9792 with 1 missing, elapsed time: 36.260
# Imputing row 2201/9792 with 1 missing, elapsed time: 36.266
# Imputing row 2301/9792 with 1 missing, elapsed time: 36.271
# Imputing row 2401/9792 with 0 missing, elapsed time: 36.276
# Imputing row 2501/9792 with 0 missing, elapsed time: 36.281
# Imputing row 2601/9792 with 1 missing, elapsed time: 36.287
# Imputing row 2701/9792 with 0 missing, elapsed time: 36.293
# Imputing row 2801/9792 with 0 missing, elapsed time: 36.298
# Imputing row 2901/9792 with 0 missing, elapsed time: 36.304
# Imputing row 3001/9792 with 1 missing, elapsed time: 36.309
# Imputing row 3101/9792 with 1 missing, elapsed time: 36.315
# Imputing row 3201/9792 with 0 missing, elapsed time: 36.322
# Imputing row 3301/9792 with 0 missing, elapsed time: 36.329
# Imputing row 3401/9792 with 1 missing, elapsed time: 36.338
# Imputing row 3501/9792 with 1 missing, elapsed time: 36.345
# Imputing row 3601/9792 with 3 missing, elapsed time: 36.361
# Imputing row 3701/9792 with 1 missing, elapsed time: 36.374
# Imputing row 3801/9792 with 1 missing, elapsed time: 36.388
# Imputing row 3901/9792 with 0 missing, elapsed time: 36.397
# Imputing row 4001/9792 with 0 missing, elapsed time: 36.403
# Imputing row 4101/9792 with 0 missing, elapsed time: 36.412
# Imputing row 4201/9792 with 0 missing, elapsed time: 36.423
# Imputing row 4301/9792 with 1 missing, elapsed time: 36.428
# Imputing row 4401/9792 with 0 missing, elapsed time: 36.434
# Imputing row 4501/9792 with 1 missing, elapsed time: 36.440
# Imputing row 4601/9792 with 2 missing, elapsed time: 36.446
# Imputing row 4701/9792 with 0 missing, elapsed time: 36.452
# Imputing row 4801/9792 with 3 missing, elapsed time: 36.457
# Imputing row 4901/9792 with 0 missing, elapsed time: 36.462
# Imputing row 5001/9792 with 1 missing, elapsed time: 36.469
# Imputing row 5101/9792 with 1 missing, elapsed time: 36.478
# Imputing row 5201/9792 with 0 missing, elapsed time: 36.489
# Imputing row 5301/9792 with 1 missing, elapsed time: 36.496
# Imputing row 5401/9792 with 0 missing, elapsed time: 36.501
# Imputing row 5501/9792 with 2 missing, elapsed time: 36.505
# Imputing row 5601/9792 with 0 missing, elapsed time: 36.511
# Imputing row 5701/9792 with 3 missing, elapsed time: 36.517
# Imputing row 5801/9792 with 8 missing, elapsed time: 36.522
# Imputing row 5901/9792 with 0 missing, elapsed time: 36.529
# Imputing row 6001/9792 with 0 missing, elapsed time: 36.536
# Imputing row 6101/9792 with 0 missing, elapsed time: 36.543
# Imputing row 6201/9792 with 2 missing, elapsed time: 36.555
# Imputing row 6301/9792 with 1 missing, elapsed time: 36.569
# Imputing row 6401/9792 with 1 missing, elapsed time: 36.583
# Imputing row 6501/9792 with 0 missing, elapsed time: 36.596
# Imputing row 6601/9792 with 1 missing, elapsed time: 36.603
# Imputing row 6701/9792 with 1 missing, elapsed time: 36.609
# Imputing row 6801/9792 with 0 missing, elapsed time: 36.615
# Imputing row 6901/9792 with 0 missing, elapsed time: 36.622
# Imputing row 7001/9792 with 0 missing, elapsed time: 36.627
# Imputing row 7101/9792 with 1 missing, elapsed time: 36.632
# Imputing row 7201/9792 with 2 missing, elapsed time: 36.635
# Imputing row 7301/9792 with 0 missing, elapsed time: 36.639
# Imputing row 7401/9792 with 0 missing, elapsed time: 36.643
# Imputing row 7501/9792 with 1 missing, elapsed time: 36.648
# Imputing row 7601/9792 with 0 missing, elapsed time: 36.653
# Imputing row 7701/9792 with 0 missing, elapsed time: 36.656
# Imputing row 7801/9792 with 1 missing, elapsed time: 36.661
# Imputing row 7901/9792 with 11 missing, elapsed time: 36.667
# Imputing row 8001/9792 with 0 missing, elapsed time: 36.673
# Imputing row 8101/9792 with 0 missing, elapsed time: 36.679
# Imputing row 8201/9792 with 0 missing, elapsed time: 36.685
# Imputing row 8301/9792 with 1 missing, elapsed time: 36.691
# Imputing row 8401/9792 with 1 missing, elapsed time: 36.698
# Imputing row 8501/9792 with 1 missing, elapsed time: 36.703
# Imputing row 8601/9792 with 0 missing, elapsed time: 36.709
# Imputing row 8701/9792 with 1 missing, elapsed time: 36.715
# Imputing row 8801/9792 with 0 missing, elapsed time: 36.721
# Imputing row 8901/9792 with 0 missing, elapsed time: 36.726
# Imputing row 9001/9792 with 1 missing, elapsed time: 36.733
# Imputing row 9101/9792 with 0 missing, elapsed time: 36.738
# Imputing row 9201/9792 with 0 missing, elapsed time: 36.743
# Imputing row 9301/9792 with 1 missing, elapsed time: 36.748
# Imputing row 9401/9792 with 1 missing, elapsed time: 36.754
# Imputing row 9501/9792 with 3 missing, elapsed time: 36.773
# Imputing row 9601/9792 with 1 missing, elapsed time: 36.789
# Imputing row 9701/9792 with 0 missing, elapsed time: 36.801
# Imputing row 1/5910 with 0 missing, elapsed time: 13.197
# Imputing row 101/5910 with 1 missing, elapsed time: 13.203
# Imputing row 201/5910 with 1 missing, elapsed time: 13.209
# Imputing row 301/5910 with 0 missing, elapsed time: 13.212
# Imputing row 401/5910 with 1 missing, elapsed time: 13.215
# Imputing row 501/5910 with 0 missing, elapsed time: 13.218
# Imputing row 601/5910 with 1 missing, elapsed time: 13.221
# Imputing row 701/5910 with 1 missing, elapsed time: 13.225
# Imputing row 801/5910 with 1 missing, elapsed time: 13.228
# Imputing row 901/5910 with 0 missing, elapsed time: 13.233
# Imputing row 1001/5910 with 3 missing, elapsed time: 13.236
# Imputing row 1101/5910 with 0 missing, elapsed time: 13.240
# Imputing row 1201/5910 with 1 missing, elapsed time: 13.243
# Imputing row 1301/5910 with 1 missing, elapsed time: 13.247
# Imputing row 1401/5910 with 1 missing, elapsed time: 13.250
# Imputing row 1501/5910 with 0 missing, elapsed time: 13.253
# Imputing row 1601/5910 with 0 missing, elapsed time: 13.256
# Imputing row 1701/5910 with 0 missing, elapsed time: 13.259
# Imputing row 1801/5910 with 1 missing, elapsed time: 13.263
# Imputing row 1901/5910 with 0 missing, elapsed time: 13.267
# Imputing row 2001/5910 with 1 missing, elapsed time: 13.271
# Imputing row 2101/5910 with 1 missing, elapsed time: 13.278
# Imputing row 2201/5910 with 1 missing, elapsed time: 13.282
# Imputing row 2301/5910 with 0 missing, elapsed time: 13.287
# Imputing row 2401/5910 with 1 missing, elapsed time: 13.291
# Imputing row 2501/5910 with 0 missing, elapsed time: 13.295
# Imputing row 2601/5910 with 1 missing, elapsed time: 13.300
# Imputing row 2701/5910 with 1 missing, elapsed time: 13.306
# Imputing row 2801/5910 with 0 missing, elapsed time: 13.309
# Imputing row 2901/5910 with 1 missing, elapsed time: 13.313
# Imputing row 3001/5910 with 0 missing, elapsed time: 13.316
# Imputing row 3101/5910 with 0 missing, elapsed time: 13.319
# Imputing row 3201/5910 with 0 missing, elapsed time: 13.323
# Imputing row 3301/5910 with 4 missing, elapsed time: 13.327
# Imputing row 3401/5910 with 1 missing, elapsed time: 13.333
# Imputing row 3501/5910 with 0 missing, elapsed time: 13.336
# Imputing row 3601/5910 with 1 missing, elapsed time: 13.338
# Imputing row 3701/5910 with 0 missing, elapsed time: 13.342
# Imputing row 3801/5910 with 0 missing, elapsed time: 13.346
# Imputing row 3901/5910 with 0 missing, elapsed time: 13.350
# Imputing row 4001/5910 with 1 missing, elapsed time: 13.354
# Imputing row 4101/5910 with 0 missing, elapsed time: 13.358
# Imputing row 4201/5910 with 0 missing, elapsed time: 13.363
# Imputing row 4301/5910 with 0 missing, elapsed time: 13.365
# Imputing row 4401/5910 with 0 missing, elapsed time: 13.367
# Imputing row 4501/5910 with 1 missing, elapsed time: 13.369
# Imputing row 4601/5910 with 1 missing, elapsed time: 13.373
# Imputing row 4701/5910 with 0 missing, elapsed time: 13.376
# Imputing row 4801/5910 with 0 missing, elapsed time: 13.380
# Imputing row 4901/5910 with 0 missing, elapsed time: 13.384
# Imputing row 5001/5910 with 0 missing, elapsed time: 13.388
# Imputing row 5101/5910 with 1 missing, elapsed time: 13.392
# Imputing row 5201/5910 with 0 missing, elapsed time: 13.395
# Imputing row 5301/5910 with 0 missing, elapsed time: 13.400
# Imputing row 5401/5910 with 0 missing, elapsed time: 13.404
# Imputing row 5501/5910 with 0 missing, elapsed time: 13.407
# Imputing row 5601/5910 with 1 missing, elapsed time: 13.412
# Imputing row 5701/5910 with 5 missing, elapsed time: 13.419
# Imputing row 5801/5910 with 2 missing, elapsed time: 13.426
# Imputing row 5901/5910 with 1 missing, elapsed time: 13.435

# %% [markdown]
# #### 3.B.c Expectation-Maximization (EM) Imputation

# %%
em = Data.do_EM_imputation()
set_new_headers(em)

# %% [markdown]
# #### 3.B.d MICE imputation (Multivariate Imputation using Chained Equation)

# %%
mice = Data.do_MICE_imputation()
set_new_headers(em)

# %% [markdown]
# In the above 4 steps, we have successfully created 4 differently imputed dataframes using: Mean, k-NN, EM and MICE techniques respectively.
#
# Here below, we create a dictionary of all the imputed dataframes to re-use them in the future.

# %%
imputed_dataframes_dictionary = OrderedDict()
imputed_dataframes_dictionary['Mean'] = m
imputed_dataframes_dictionary['k-NN'] = knn
imputed_dataframes_dictionary['EM'] = em
imputed_dataframes_dictionary['MICE'] = mice

# %% [markdown]
# ### 3.C Dealing with imbalanced data
#
# In the steps seen above, we have successfully dealt with the missing data. But we have not dealt with the class imbalance in the data. Data Imbalance is a condition where the samples belonging to one or more 'majority' class labels of a labelled dataset heavily outnumber the sample belonging to the other 'minority' classes.
#
# Data imbalance critically affects the modeling as the models won't have sufficient data belonging to minority classes to train on and this leads to biased models, ultimately leading to poor performance on test data.
#
# Examining severity of imbalance....

# %%
def data_imbalance(dataframes):
    for i in range(len(dataframes)):
        print('Dataset: '+str(i+1)+' ndyear')
        print(dataframes[i].groupby('Y').size())
        minority_percent = (dataframes[i]['Y'].tolist().count(1) / len(dataframes[i]['Y'].tolist()))*100
        print('Minority (label 1) percentage: '+  str(minority_percent) + '%')
        print('-'*64)
        
data_imbalance(dataframes)
# Out:
# Dataset: 1 ndyear
# Y
# 0    6756
# 1     271
# dtype: int64
# Minority (label 1) percentage: 3.856553294435748%
# ----------------------------------------------------------------
# Dataset: 2 ndyear
# Y
# 0    9773
# 1     400
# dtype: int64
# Minority (label 1) percentage: 3.931976801336872%
# ----------------------------------------------------------------
# Dataset: 3 ndyear
# Y
# 0    10008
# 1      495
# dtype: int64
# Minority (label 1) percentage: 4.712939160239932%
# ----------------------------------------------------------------
# Dataset: 4 ndyear
# Y
# 0    9277
# 1     515
# dtype: int64
# Minority (label 1) percentage: 5.259395424836601%
# ----------------------------------------------------------------
# Dataset: 5 ndyear
# Y
# 0    5500
# 1     410
# dtype: int64
# Minority (label 1) percentage: 6.937394247038917%
# ----------------------------------------------------------------

# %% [markdown]
# There is a lot of data imbalance for our datasets, as indicated by the percentage of minority class (label `1`) samples among their datasets. This huge magnitude of data imbalance will not train models well.

# %% [markdown]
# #### 3.C.a Oversampling with SMOTE (Synthetic Minority Over Sampling Technique)

# %%
class OVERSAMPLING:
    
    """ Contains all methods required for performing SMOTE oversampling.........__init__(self) not required"""

    def split_dataframes_features_labels(self,dfs):
        """ Split the features and labels into separate dataframes for all the original dataframes """ 
        feature_dataframes = [dfs[i].iloc[:,0:64] for i in range(len(dfs))]
        label_dataframes = [dfs[i].iloc[:,64] for i in range(len(dfs))]
        return feature_dataframes, label_dataframes    
    
    
    def oversample_data_SMOTE(self,dfs, verbose=False):
        """ Performs oversampling for dataframes passed in as an argument"""
        smote = SMOTE('auto' , random_state=42, k_neighbors=10)
        #Split the features and labels for each dataframe
        feature_dataframes, label_dataframes = self.split_dataframes_features_labels(dfs)
        resampled_feature_arrays = []
        resampled_label_arrays = []
        for i in range(len(dfs)):
            if verbose: print('Dataset: ' + str(i+1) + 'year:')
            if verbose: print('Original dataset shape {}'.format(Counter(label_dataframes[i])))
            dfi_features_res, dfi_label_res = smote.fit_sample(feature_dataframes[i], label_dataframes[i])
            if verbose: print('Resampled dataset shape {}\n'.format(Counter(dfi_label_res)))
            # Append the resampled feature and label arrays of ith dataframe to their respective list of arrays    
            resampled_feature_arrays.append(dfi_features_res)
            resampled_label_arrays.append(dfi_label_res)        
        return resampled_feature_arrays, resampled_label_arrays

    
    def restructure_arrays_to_dataframes(self, feature_arrays, label_arrays):  
        """ Utility Function to convert the arrays of features and labels to pandas dataframes, and then join them. Also re-assign the columns headers """
        resampled_dfs = []
        for i in range(len(feature_arrays)):
            feature_df = pd.DataFrame(data=feature_arrays[i])
            label_df = pd.DataFrame(data=label_arrays[i])
            # Must set the column header for label_df, otherwise it wont join with feature_df, as columns overlap (with col names '0')
            label_df.columns=['Y'] 
            resampled_dfs.append(feature_df.join(label_df))
        # re-assign the column headers for features and labels    
        self.set_headers(resampled_dfs)
        return resampled_dfs

    def set_headers(self,dataframes):
        cols = ['X' + str(i+1) for i in range(len(dataframes[0].columns)-1)]
        cols.append('Y')
        for df in dataframes:
            df.columns = cols


    def perform_oversampling_on_imputed_dataframes(self, df_dict):
        """ Performs SMOTE on all imputed dataframes and stores them in a dictionary"""
        imputed_oversampled_dataframes_dictionary = OrderedDict()
        for key,dfs in df_dict.items():
            print('SMOTE Oversampling for ' + key + ' imputed dataframes\n')
            smote_feature_arrays, smote_label_arrays = self.oversample_data_SMOTE(dfs, verbose=True)
            oversampled_dataframes = self.restructure_arrays_to_dataframes(smote_feature_arrays, smote_label_arrays)
            imputed_oversampled_dataframes_dictionary[key] = oversampled_dataframes
            print('-'*100)
        return imputed_oversampled_dataframes_dictionary

# %%
imputed_oversampled_dataframes_dictionary = OVERSAMPLING().perform_oversampling_on_imputed_dataframes(imputed_dataframes_dictionary)
# Out:
# SMOTE Oversampling for Mean imputed dataframes
#
# Dataset: 1year:
# Original dataset shape Counter({0.0: 6756, 1.0: 271})
# Resampled dataset shape Counter({0.0: 6756, 1.0: 6756})
#
# Dataset: 2year:
# Original dataset shape Counter({0.0: 9773, 1.0: 400})
# Resampled dataset shape Counter({0.0: 9773, 1.0: 9773})
#
# Dataset: 3year:
# Original dataset shape Counter({0.0: 10008, 1.0: 495})
# Resampled dataset shape Counter({0.0: 10008, 1.0: 10008})
#
# Dataset: 4year:
# Original dataset shape Counter({0.0: 9277, 1.0: 515})
# Resampled dataset shape Counter({0.0: 9277, 1.0: 9277})
#
# Dataset: 5year:
# Original dataset shape Counter({0.0: 5500, 1.0: 410})
# Resampled dataset shape Counter({0.0: 5500, 1.0: 5500})
#
# ----------------------------------------------------------------------------------------------------
# SMOTE Oversampling for k-NN imputed dataframes
#
# Dataset: 1year:
# Original dataset shape Counter({0.0: 6756, 1.0: 271})
# Resampled dataset shape Counter({0.0: 6756, 1.0: 6756})
#
# Dataset: 2year:
# Original dataset shape Counter({0.0: 9773, 1.0: 400})
# Resampled dataset shape Counter({0.0: 9773, 1.0: 9773})
#
# Dataset: 3year:
# Original dataset shape Counter({0.0: 10008, 1.0: 495})
# Resampled dataset shape Counter({0.0: 10008, 1.0: 10008})
#
# Dataset: 4year:
# Original dataset shape Counter({0.0: 9277, 1.0: 515})
# Resampled dataset shape Counter({0.0: 9277, 1.0: 9277})
#
# Dataset: 5year:
# Original dataset shape Counter({0.0: 5500, 1.0: 410})
# Resampled dataset shape Counter({0.0: 5500, 1.0: 5500})
#
# ----------------------------------------------------------------------------------------------------
# SMOTE Oversampling for EM imputed dataframes
#
# Dataset: 1year:
# Original dataset shape Counter({0.0: 6756, 1.0: 271})
# Resampled dataset shape Counter({0.0: 6756, 1.0: 6756})
#
# Dataset: 2year:
# Original dataset shape Counter({0.0: 9773, 1.0: 400})
# Resampled dataset shape Counter({0.0: 9773, 1.0: 9773})
#
# Dataset: 3year:
# Original dataset shape Counter({0.0: 10008, 1.0: 495})
# Resampled dataset shape Counter({0.0: 10008, 1.0: 10008})
#
# Dataset: 4year:
# Original dataset shape Counter({0.0: 9277, 1.0: 515})
# Resampled dataset shape Counter({0.0: 9277, 1.0: 9277})
#
# Dataset: 5year:
# Original dataset shape Counter({0.0: 5500, 1.0: 410})
# Resampled dataset shape Counter({0.0: 5500, 1.0: 5500})
#
# ----------------------------------------------------------------------------------------------------
# SMOTE Oversampling for MICE imputed dataframes
#
# Dataset: 1year:
# Original dataset shape Counter({0.0: 6756, 1.0: 271})
# Resampled dataset shape Counter({0.0: 6756, 1.0: 6756})
#
# Dataset: 2year:
# Original dataset shape Counter({0.0: 9773, 1.0: 400})
# Resampled dataset shape Counter({0.0: 9773, 1.0: 9773})
#
# Dataset: 3year:
# Original dataset shape Counter({0.0: 10008, 1.0: 495})
# Resampled dataset shape Counter({0.0: 10008, 1.0: 10008})
#
# Dataset: 4year:
# Original dataset shape Counter({0.0: 9277, 1.0: 515})
# Resampled dataset shape Counter({0.0: 9277, 1.0: 9277})
#
# Dataset: 5year:
# Original dataset shape Counter({0.0: 5500, 1.0: 410})
# Resampled dataset shape Counter({0.0: 5500, 1.0: 5500})
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. Data Modeling: Building Classification Models
#
# ### 4.A K-Fold Cross Validation

# %%
def prepare_kfold_cv_data(k, X, y, verbose=False):
    X = X.values
    y = y.values
    kf = KFold(n_splits=k, shuffle=False, random_state=42)
    X_train = []
    y_train = []
    X_test = []
    y_test = []
    
    for train_index, test_index in kf.split(X):
        X_train.append(X[train_index])
        y_train.append(y[train_index])
        X_test.append(X[test_index])
        y_test.append(y[test_index])
    return X_train, y_train, X_test, y_test

# %% [markdown]
# ### 4.B MODELS
#
# ### 4.B.a Gaussian Naive Bayes classifier

# %%
# Gaussian Naive Bayes classifier
gnb_classifier = GaussianNB()

# %% [markdown]
# ### 4.B.b Logistic Regression classifier

# %%
# Logistic Regression classifier
lr_classifier = LogisticRegression(penalty = 'l1', random_state = 0, solver='liblinear')

# %% [markdown]
# ### 4.B.c Decision Tree Classifier

# %%
# Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### 4.B.d Random Forest Classifier

# %%
# Random Forest Classifier
rf_classifier = RandomForestClassifier(n_estimators = 5, criterion = 'entropy')

# %% [markdown]
# ### 4.B.e Extreme Gradient Boosting Classifier

# %%
# eXtreme Gradient Boosting Classifier (XGBClassifier)
xgb_classifier = XGBClassifier()

# %% [markdown]
# ### 4.B.f Balanced Bagging Classifier

# %%
# Balanced Bagging Classifier
bb_classifier = BalancedBaggingClassifier(base_estimator = RandomForestClassifier(criterion='entropy'), n_estimators = 5, bootstrap = True)

# %%
# creating a dictionary of models
models_dictionary = OrderedDict()

models_dictionary['Gaussian Naive Bayes'] = gnb_classifier
models_dictionary['Logistic Regression'] = lr_classifier
models_dictionary['Decision Tree'] = dt_classifier
models_dictionary['Extreme Gradient Boosting'] = xgb_classifier
models_dictionary['Random Forest'] = rf_classifier
models_dictionary['Balanced Bagging'] = bb_classifier

# %%
# perform data modeling
def perform_data_modeling(_models_, _imputers_, verbose=False, k_folds=5):
    
    # 7 Models
    # 4 Imputers
    # 5 datasets (for 5 years)
    # 7 metrics, averaged over all the K-Folds
    model_results = OrderedDict()
    
    # Iterate over the models
    for model_name, clf in _models_.items():
        if verbose: print("-"*120, "\n", "Model: " + '\033[1m' + model_name + '\033[0m' + " Classifier")
        imputer_results = OrderedDict()
        
        # Iterate over the different imputed_data mechanisms (Mean, k-NN, EM, MICE)
        for imputer_name, dataframes_list in _imputers_.items():
            if verbose: print('\tImputer Technique: ' + '\033[1m' + imputer_name + '\033[0m')
            
            # call the split_dataframes_features_labels function to get a list of features and labels for all the dataframes
            feature_dfs, label_dfs = split_dataframes_features_labels(dataframes_list)            
            
            year_results = OrderedDict()
            
            # Iterate over dataframe_list individually
            for df_index in range(len(dataframes_list)):
                if verbose: print('\t\tDataset: ' + '\033[1m' + str(df_index+1) + 'year' + '\033[0m')
                
                # Calling the 'prepare_kfold_cv_data' returns lists of features and labels 
                # for train and test sets respectively.
                # The number of items in the list is equal to k_folds
                X_train_list, y_train_list, X_test_list, y_test_list = prepare_kfold_cv_data(k_folds, feature_dfs[df_index], label_dfs[df_index], verbose)
                
                metrics_results = OrderedDict()
                accuracy_list = np.zeros([k_folds])
                precision_list = np.zeros([k_folds,2])
                recall_list = np.zeros([k_folds,2])
                TN_list = np.zeros([k_folds])
                FP_list = np.zeros([k_folds])
                FN_list = np.zeros([k_folds])
                TP_list = np.zeros([k_folds])                
                
                # Iterate over all the k-folds
                for k_index in range(k_folds):
                    X_train = X_train_list[k_index]
                    y_train = y_train_list[k_index]
                    X_test = X_test_list[k_index]
                    y_test = y_test_list[k_index]
                    
                    # Fit the model and 
                    clf = clf.fit(X_train, y_train)
                    y_test_predicted = clf.predict(X_test)
                    
                    #code for calculating accuracy 
                    _accuracy_ = accuracy_score(y_test, y_test_predicted, normalize=True)
                    accuracy_list[k_index] = _accuracy_
                    
                    #code for calculating recall 
                    _recalls_ = recall_score(y_test, y_test_predicted, average=None)
                    recall_list[k_index] = _recalls_
                    
                    #code for calculating precision 
                    _precisions_ = precision_score(y_test, y_test_predicted, average=None)
                    precision_list[k_index] = _precisions_
                    
                    #code for calculating confusion matrix 
                    _confusion_matrix_ = confusion_matrix(y_test, y_test_predicted)
                    TN_list[k_index] = _confusion_matrix_[0][0]
                    FP_list[k_index] = _confusion_matrix_[0][1]
                    FN_list[k_index] = _confusion_matrix_[1][0]
                    TP_list[k_index] = _confusion_matrix_[1][1]
                
                # creating a metrics dictionary
                metrics_results['Accuracy'] = np.mean(accuracy_list)
                metrics_results['Precisions'] = np.mean(precision_list, axis=0)
                metrics_results['Recalls'] = np.mean(recall_list, axis=0)
                metrics_results['TN'] = np.mean(TN_list)
                metrics_results['FP'] = np.mean(FP_list)
                metrics_results['FN'] = np.mean(FN_list)
                metrics_results['TP'] = np.mean(TP_list)
                
                if verbose:
                    print('\t\t\tAccuracy:', metrics_results['Accuracy'])
                    print('\t\t\tPrecision:', metrics_results['Precisions'])
                    print('\t\t\tRecall:', metrics_results['Recalls'])
                
                year_results[str(df_index+1)+'year'] = metrics_results   
                
            imputer_results[imputer_name] = year_results
            
        model_results[model_name] = imputer_results  
        
    return model_results

# %%
results = perform_data_modeling(models_dictionary, imputed_oversampled_dataframes_dictionary, verbose=True, k_folds=5)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
#  Model: Gaussian Naive Bayes Classifier
# 	Imputer Technique: Mean
# 		Dataset: 1year
# 			Accuracy: 0.5156118171190658
# 			Precision: [0.55384615 0.50140311]
# 			Recall: [0.02427755 0.59385805]
# 		Dataset: 2year
# 			Accuracy: 0.512558257912261
# 			Precision: [0.50166667 0.50007918]
# 			Recall: [0.02522294 0.5874152 ]
# 		Dataset: 3year
# 			Accuracy: 0.5196079463878615
# 			Precision: [0.53333333 0.50124288]
# 			Recall: [0.03492381 0.58701092]
# 		Dataset: 4year
# 			Accuracy: 0.5144681833930015
# 			Precision: [0.51151515 0.50056402]
# 			Recall: [0.03805172 0.5774183 ]
# 		Dataset: 5year
# 			Accuracy: 0.517090909090909
# 			Precision: [0.51764706 0.50100913]
# 			Recall: [0.04245455 0.57654545]
# 	Imputer Technique: k-NN
# 		Dataset: 1year
# 			Accuracy: 0.5167952761317647
# 			Precision: [0.54647887 0.50133029]
# 			Recall: [0.0268676  0.59230408]
# 		Dataset: 2year
# 			Accuracy: 0.5118931523358452
# 			Precision: [0.51333333 0.50044867]
# 			Recall: [0.02522315 0.58746619]
# 		Dataset: 3year
# 			Accuracy: 0.5203071347837773
# 			Precision: [0.53552632 0.5014282 ]
# 			Recall: [0.03772165 0.58526228]
# 		Dataset: 4year
# 			Accuracy: 0.5134441570591111
# 			Precision: [0.51098266 0.50056529]
# 			Recall: [0.03789015 0.57655607]
# 		Dataset: 5year
# 			Accuracy: 0.5261818181818182
# 			Precision: [0.52105263 0.5015625 ]
# 			Recall: [0.05454545 0.57454545]
# 	Imputer Technique: EM
# 		Dataset: 1year
# 			Accuracy: 0.5139094292521975
# 			Precision: [0.53066667 0.50095166]
# 			Recall: [0.02398142 0.59156465]
# 		Dataset: 2year
# 			Accuracy: 0.5106653214857968
# 			Precision: [0.51451613 0.50050198]
# 			Recall: [0.02517217 0.58639177]
# 		Dataset: 3year
# 			Accuracy: 0.5279004657595714
# 			Precision: [0.53369565 0.50164965]
# 			Recall: [0.04681435 0.5841634 ]
# 		Dataset: 4year
# 			Accuracy: 0.5138216172361472
# 			Precision: [0.51170213 0.50065285]
# 			Recall: [0.03999227 0.57499352]
# 		Dataset: 5year
# 			Accuracy: 0.548
# 			Precision: [0.50317686 0.57362637]
# 			Recall: [0.27927273 0.37481818]
# 	Imputer Technique: MICE
# 		Dataset: 1year
# 			Accuracy: 0.5116151064981668
# 			Precision: [0.53333333 0.50091047]
# 			Recall: [0.02250076 0.59067598]
# 		Dataset: 2year
# 			Accuracy: 0.5088750663267075
# 			Precision: [0.50638298 0.50018349]
# 			Recall: [0.01908359 0.59007534]
# 		Dataset: 3year
# 			Accuracy: 0.5157614181970914
# 			Precision: [0.53492063 0.50116069]
# 			Recall: [0.02837908 0.58955885]
# 		Dataset: 4year
# 			Accuracy: 0.5140375847720152
# 			Precision: [0.51555556 0.50061521]
# 			Recall: [0.03239246 0.58275387]
# 		Dataset: 5year
# 			Accuracy: 0.5237272727272726
# 			Precision: [0.53061224 0.50383632]
# 			Recall: [0.06209091 0.56845455]
# ------------------------------------------------------------------------------------------------------------------------
#  Model: Logistic Regression Classifier
# 	Imputer Technique: Mean
# 		Dataset: 1year
# 			Accuracy: 0.4153368806707354
# 			Precision: [0.53716881 0.53569877]
# 			Recall: [0.29397065 0.25778045]
# 		Dataset: 2year
# 			Accuracy: 0.42412970527060967
# 			Precision: [0.54871795 0.53376623]
# 			Recall: [0.27025958 0.29374314]
# 		Dataset: 3year
# 			Accuracy: 0.5108918560829628
# 			Precision: [0.55206612 0.53824166]
# 			Recall: [0.31522079 0.33975532]
# 		Dataset: 4year
# 			Accuracy: 0.4837181657794522
# 			Precision: [0.53941825 0.54583576]
# 			Recall: [0.33687682 0.28923288]
# 		Dataset: 5year
# 			Accuracy: 0.6385454545454545
# 			Precision: [0.55453774 0.56297747]
# 			Recall: [0.43209091 0.36490909]
# 	Imputer Technique: k-NN
# 		Dataset: 1year
# 			Accuracy: 0.3854393492659553
# 			Precision: [0.53836576 0.53493296]
# 			Recall: [0.27458199 0.24741568]
# 		Dataset: 2year
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-342745435bd0> in <module>
# ----> 1 results = perform_data_modeling(models_dictionary, imputed_oversampled_dataframes_dictionary, verbose=True, k_folds=5)
#
# <ipython-input-60-e515c45fa1db> in perform_data_modeling(_models_, _imputers_, verbose, k_folds)
#      48
#      49                     # Fit the model and
# ---> 50                     clf = clf.fit(X_train, y_train)
#      51                     y_test_predicted = clf.predict(X_test)
#      52
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1354                               " 'solver' is set to 'liblinear'. Got 'n_jobs'"
#    1355                               " = {}.".format(effective_n_jobs(self.n_jobs)))
# -> 1356             self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#    1357                 X, y, self.C, self.fit_intercept, self.intercept_scaling,
#    1358                 self.class_weight, self.penalty, self.dual, self.verbose,
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     964
#     965     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
# --> 966     raw_coef_, n_iter_ = liblinear.train_wrap(
#     967         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     968         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
#
# KeyboardInterrupt:

# %% [markdown]
# ## Model Analysis
#
# ### Model Ranking

# %%
# model -> imputer -> year
def perform_model_ranking(models, imputers, results):
    column_headers = ['-'] + list(imputers.keys())
    rows = []
    for model_name, model_details in results.items():
        row = [model_name]
        for imputer_name, imputer_details in model_details.items():
            mean_accuracy = 0
            for year, metrics in imputer_details.items():
                mean_accuracy += metrics['Accuracy']
            mean_accuracy = mean_accuracy/len(imputer_details)
            row.append(mean_accuracy)
        rows.append(row)
    results_df = pd.DataFrame(data=rows, columns = column_headers)
    return results_df

# %%
perform_model_ranking(models_dictionary, imputed_oversampled_dataframes_dictionary, results)

# %% [markdown]
# ### Balanced Bagging: Effect of varying number of estimators on the accuracy scores on different datasets

# %%
# This list stores results of Balanced Bagging classifier obtained by running it for 
# various values of number of estimators in the range of 1 to 30
results_by_estimators = []
for i in range(29):
    models_dictionary['Balanced Bagging'] = BalancedBaggingClassifier(base_estimator = RandomForestClassifier(criterion='entropy'), n_estimators = i+1, bootstrap = True)
    results = perform_data_modeling(models_dictionary, imputed_oversampled_dataframes_dictionary, verbose=True, k_folds=5)
    results_by_estimators.append(results)

# %% [markdown]
# ### Balanced Bagging: Plotting effect of number of estimators on Accuracy

# %%
year1_values = []
year2_values = []
year3_values = []
year4_values = []
year5_values = []

# extract corresponding Balanced bagging with Mean imputation
# classification metrics 
def extract_actual_values_from_dict(curr_dict):
    temp_dict = curr_dict['Balanced Bagging']
    return temp_dict['Mean']

for i in range(29):
    curr_dict = results_by_estimators[i]
    curr_result = extract_actual_values_from_dict(curr_dict)
    
        
    year_1_result = curr_result['1year']
    year_2_result = curr_result['2year']
    year_3_result = curr_result['3year']
    year_4_result = curr_result['4year']
    year_5_result = curr_result['5year']
    year1_values.append(year_1_result['Accuracy'])
    year2_values.append(year_2_result['Accuracy'])
    year3_values.append(year_3_result['Accuracy'])
    year4_values.append(year_4_result['Accuracy'])
    year5_values.append(year_5_result['Accuracy'])

# %% [markdown]
# ### Plot of effect of number of estimators on Accuracy for Balanced Bagging classifier

# %%
import matplotlib.pyplot as plt

estimators = [i+1 for i in range(29)] 

# plot year1, year2, year3, year4 and year5 accuracy values
# for range of estimator values from 1 to 30
plt.plot(estimators, year1_values, '.b-')
plt.plot(estimators, year2_values, '.r-')
plt.plot(estimators, year3_values, '.y-')
plt.plot(estimators, year4_values, '.g-')
plt.plot(estimators, year5_values, '.m-') 
plt.xlabel("\nNumber of estimators")
plt.ylabel("Accuracy")
plt.title("\nEffect of varying number of estimators on the accuracy scores on different datasets\n")

# display legend
plt.plot(10, 0.93, '.b-', label='Year 1')
plt.plot(10, 0.93, '.r-', label='Year 2')
plt.plot(10, 0.93, '.y-', label='Year 3')
plt.plot(10, 0.93, '.g-', label='Year 4')
plt.plot(10, 0.93, '.m-', label='Year 5')

plt.legend(loc='lower right')

# %% [markdown]
# ## References
# https://docs.scipy.org/doc/numpy-1.14.0/reference/
# https://pandas.pydata.org/
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.arff.loadarff.html
# https://github.com/iskandr/fancyimpute
# https://pypi.org/project/impyute/
# http://scikit-learn.org/stable/modules/preprocessing.html
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
# https://docs.python.org/3/library/collections.html
# http://xgboost.readthedocs.io/en/latest/python/python_api.html
# http://scikit-learn.org/stable/modules/svm.html
# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
# http://contrib.scikit-learn.org/imbalanced-learn/stable/generated/imblearn.ensemble.BalancedBaggingClassifier.html
# http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
# http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html
# https://docs.python.org/2/library/random.html
# http://scikit-learn.org/stable/modules/classes.html
# _______________________________________________________________________________
# #### _____________END OF PROJECT_____
